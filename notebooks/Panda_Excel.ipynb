# %%
import pandas as pd

# %%
df = pd.read_excel("/content/drive/MyDrive/Datasets/gapminder_excel.xlsx")

# %%
df.head(
    
)
# Out:
#   continent    country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0  Americas  Argentina    5.911315e+09    6.856856e+09    7.133166e+09
# 1  Americas    Bolivia    2.677326e+09    2.127686e+09    2.180973e+09
# 2  Americas     Brazil    2.108944e+09    2.487366e+09    3.336586e+09
# 3  Americas     Canada    1.136716e+09    1.248995e+09    1.346249e+09
# 4  Americas      Chile    3.939979e+09    4.315623e+09    4.519094e+09
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0    8.052953e+09    9.443039e+09    1.007903e+09    8.997897e+09
# 1    2.586886e+09    2.980331e+09    3.548098e+09    3.156510e+09
# 2    3.429864e+09    4.985711e+09    6.660119e+09    7.030836e+09
# 3    1.607659e+09    1.897057e+09    2.209088e+09    2.289879e+09
# 4    5.106654e+09    5.494024e+09    4.756764e+09    5.095666e+09
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0    9.139671e+09    9.308419e+08    1.096728e+09    8.797641e+09
# ...

# %%
df["cont/country"] = df["continent"] + df["country"]

# %%
df["cont/country"]
# Out:
# 0               AmericasArgentina
# 1                 AmericasBolivia
# 2                  AmericasBrazil
# 3                  AmericasCanada
# 4                   AmericasChile
# 5                AmericasColombia
# 6              AmericasCosta Rica
# 7                    AmericasCuba
# 8      AmericasDominican Republic
# 9                 AmericasEcuador
# 10            AmericasEl Salvador
# 11              AmericasGuatemala
# 12                  AmericasHaiti
# 13               AmericasHonduras
# 14                AmericasJamaica
# 15                 AmericasMexico
# 16              AmericasNicaragua
# 17                 AmericasPanama
# 18               AmericasParaguay
# 19                   AmericasPeru
# 20            AmericasPuerto Rico
# 21    AmericasTrinidad and Tobago
# 22          AmericasUnited States
# 23                AmericasUruguay
# 24              AmericasVenezuela
# Name: cont/country, dtype: object

# %%
df.head()
# Out:
#   continent    country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0  Americas  Argentina    5.911315e+09    6.856856e+09    7.133166e+09
# 1  Americas    Bolivia    2.677326e+09    2.127686e+09    2.180973e+09
# 2  Americas     Brazil    2.108944e+09    2.487366e+09    3.336586e+09
# 3  Americas     Canada    1.136716e+09    1.248995e+09    1.346249e+09
# 4  Americas      Chile    3.939979e+09    4.315623e+09    4.519094e+09
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0    8.052953e+09    9.443039e+09    1.007903e+09    8.997897e+09
# 1    2.586886e+09    2.980331e+09    3.548098e+09    3.156510e+09
# 2    3.429864e+09    4.985711e+09    6.660119e+09    7.030836e+09
# 3    1.607659e+09    1.897057e+09    2.209088e+09    2.289879e+09
# 4    5.106654e+09    5.494024e+09    4.756764e+09    5.095666e+09
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0    9.139671e+09    9.308419e+08    1.096728e+09    8.797641e+09
# ...

# %%
df.nlargest(3, "gdpPercap_1967")
# Out:
#    continent      country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 24  Americas    Venezuela    7.689800e+09    9.802467e+09    8.422974e+09
# 0   Americas    Argentina    5.911315e+09    6.856856e+09    7.133166e+09
# 20  Americas  Puerto Rico    3.081960e+09    3.907156e+09    5.108345e+08
#
#     gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 24    9.541474e+09    1.050526e+09    1.314395e+09    1.115241e+09
# 0     8.052953e+09    9.443039e+09    1.007903e+09    8.997897e+09
# 20    6.929278e+09    9.123042e+09    9.770525e+09    1.033099e+09
#
#     gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 24    9.883585e+09    1.073393e+09    1.016550e+09    8.605048e+09
# 0     9.139671e+09    9.308419e+08    1.096728e+09    8.797641e+09
# 20    1.228134e+09    1.464159e+09    1.699943e+08    1.885561e+09
#
#     gdpPercap_2007         cont/country
# 24    1.141581e+09    AmericasVenezuela
# 0     1.277938e+09    AmericasArgentina
# ...

# %%
df.nsmallest(3, "gdpPercap_1967")
# Out:
#    continent  country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 23  Americas  Uruguay    5.716767e+09    6.150773e+09    5.603358e+09
# 19  Americas     Peru    3.758523e+09    4.245257e+09    4.957038e+09
# 12  Americas    Haiti    1.840367e+09    1.726888e+09    1.796589e+09
#
#     gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 23    5.444620e+08    5.703409e+09    6.504340e+09    6.920223e+09
# 19    5.788093e+08    5.937827e+09    6.281291e+09    6.434502e+09
# 12    1.452058e+09    1.654457e+09    1.874299e+09    2.011160e+09
#
#     gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 23    7.452399e+09    8.137005e+09    9.230241e+09    7.727002e+09
# 19    6.360943e+09    4.446381e+09    5.838348e+09    5.909020e+09
# 12    1.823016e+09    1.456310e+09    1.341727e+09    1.270365e+09
#
#     gdpPercap_2007     cont/country
# 23    1.061146e+09  AmericasUruguay
# 19    7.408906e+09     AmericasPeru
# ...

# %%
df.dtypes
# Out:
# continent          object
# country            object
# gdpPercap_1952    float64
# gdpPercap_1957    float64
# gdpPercap_1962    float64
# gdpPercap_1967    float64
# gdpPercap_1972    float64
# gdpPercap_1977    float64
# gdpPercap_1982    float64
# gdpPercap_1987    float64
# gdpPercap_1992    float64
# gdpPercap_1997    float64
# gdpPercap_2002    float64
# gdpPercap_2007    float64
# cont/country       object
# dtype: object

# %%
df["gdpPercap_1957"].min()
# Out:
# 41003934.0

# %%
pd.to_numeric(df["gdpPercap_1957"].min())
# Out:
# 41003934.0

# %%
df["gdpPercap_1957"].value_counts(ascending=False).plot.bar()

# %%
df["gdpPercap_1957"].value_counts(ascending=False).plot.barh();

# %%
df.groupby(df["cont/country"])["gdpPercap_1957"].sum().plot.pie();

# %%
# adding title 
import matplotlib.pyplot as plt
df["country"].value_counts(ascending=True).plot.barh(title="Total", color="red")
plt.xlabel("País")
plt.ylabel("Total país");

# %%
#changing style
plt.style.use("ggplot")

# %%
# adding title 
df["country"].value_counts(ascending=True).plot.barh(title="Total", color="purple")
plt.xlabel("País")
plt.ylabel("Total país");
plt.legend()

# %%
df.groupby(df["cont/country"])["gdpPercap_1957"].sum().plot()
plt.xlabel("País")
plt.ylabel("Total país")
plt.legend();

# %%
df.groupby(df["cont/country"])["gdpPercap_1957"].sum().plot()
plt.xlabel("País")
plt.ylabel("Total país")
plt.legend()
plt.savefig("grafico-total.png");
